# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import plotly
from plotly import tools
plotly.offline.init_notebook_mode(connected=True)
from data_analysis_clb.data import read_observations

df = read_observations(['LB','MUZ'],2018)
df = df[(df.index > '2018-12-8') & (df.index < '2018-12-11')]
dflb = df[df.site == 'LB']
dfmuz = df[df.site == 'MUZ']
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# /home/merzisenh/data/DONNEES_LAC_BLANC/2018_2019/SA-LACBLANC/CR1000_IP_LB_Lacb.dat
# /home/merzisenh/data/DONNEES_LAC_BLANC/2018_2019/SA-MUZELLE/IP-Muzelle_Muze.dat

# %%
df.columns

# %%
import plotly.graph_objs as go

# %%
df.columns

# %%
filter_ = (dflb.htnstd < 4) & (dflb.htnavg > -10)

htnavg = go.Scatter(x=list(dflb.index[filter_]),y=list(dflb.htnavg[filter_]),mode='markers')
htnmax = go.Scatter(x=list(dflb.index[filter_]),y=list(dflb.htnmax[filter_]),mode='markers')
wspeed = go.Scatter(x=list(dflb.index[filter_]),y=list(dflb.windspeed[filter_]),mode='markers')


fig = go.Figure(data=[htnavg,htnmax,wspeed])
plotly.offline.iplot(fig)
# Out:
# <div id="3540bc48-f7c8-4fce-9a31-29ae85041a77" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("3540bc48-f7c8-4fce-9a31-29ae85041a77", [{"x": ["2018-12-08 00:10:00", "2018-12-08 00:20:00", "2018-12-08 00:30:00", "2018-12-08 00:40:00", "2018-12-08 00:50:00", "2018-12-08 01:00:00", "2018-12-08 01:10:00", "2018-12-08 01:20:00", "2018-12-08 01:30:00", "2018-12-08 01:40:00", "2018-12-08 01:50:00", "2018-12-08 02:00:00", "2018-12-08 02:10:00", "2018-12-08 02:20:00", "2018-12-08 02:30:00", "2018-12-08 02:40:00", "2018-12-08 02:50:00", "2018-12-08 03:00:00", "2018-12-08 03:10:00", "2018-12-08 03:20:00", "2018-12-08 03:30:00", "2018-12-08 03:40:00", "2018-12-08 03:50:00", "2018-12-08 04:00:00", "2018-12-08 04:10:00", "2018-12-08 04:20:00", "2018-12-08 04:30:00", "2018-12-08 04:40:00", "2018-12-08 04:50:00", 
# ...

# %%
plotly.plotly.plot(fig)
# Out:
# 'https://plot.ly/~Schizopetalus/12'

# %%
htnstd = go.Figure([go.Scatter(x=df.index,y=df.htnstd,mode='markers')])

# %%
min(dflb.htnavg)

# %%
fig = plotly.plotly.get_figure("https://plot.ly/~Schizopetalus/9/")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-718e660c65d1> in <module>()
# ----> 1 fig = plotly.plotly.get_figure("https://plot.ly/~Schizopetalus/9/")
#
# ~/local/virtualenvs/py3/lib/python3.5/site-packages/plotly/plotly/plotly.py in get_figure(file_owner_or_url, file_id, raw)
#     498     if raw:
#     499         return figure
# --> 500     return tools.get_graph_obj(figure, obj_type='Figure')
#     501
#     502
#
# ~/local/virtualenvs/py3/lib/python3.5/site-packages/plotly/tools.py in get_graph_obj(obj, obj_type)
#    1412             "'{}' is not a recognized graph_obj.".format(obj_type)
#    1413         )
# -> 1414     return cls(obj)
#    1415
#    1416
#
# ~/local/virtualenvs/py3/lib/python3.5/site-packages/plotly/graph_objs/_figure.py in __init__(self, data, layout, frames, skip_invalid)
#     447             is invalid AND skip_invalid is False
# ...

# %%
plotly.tools.set_credentials_file(username='Schizopetalus', api_key='JsmneycGjwcIEygWFi2u')

# %%
fig = plotly.plotly.get_figure("https://plot.ly/~Schizopetalus/9/")

# %%
fig = plotly.plotly.get_figure("https://plot.ly/~jackp/10495/")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-2d13e9d8f670> in <module>()
# ----> 1 fig = plotly.plotly.get_figure("https://plot.ly/~jackp/10495/")
#
# ~/local/virtualenvs/py3/lib/python3.5/site-packages/plotly/plotly/plotly.py in get_figure(file_owner_or_url, file_id, raw)
#     498     if raw:
#     499         return figure
# --> 500     return tools.get_graph_obj(figure, obj_type='Figure')
#     501
#     502
#
# ~/local/virtualenvs/py3/lib/python3.5/site-packages/plotly/tools.py in get_graph_obj(obj, obj_type)
#    1412             "'{}' is not a recognized graph_obj.".format(obj_type)
#    1413         )
# -> 1414     return cls(obj)
#    1415
#    1416
#
# ~/local/virtualenvs/py3/lib/python3.5/site-packages/plotly/graph_objs/_figure.py in __init__(self, data, layout, frames, skip_invalid)
#     447             is invalid AND skip_invalid is False
# ...
